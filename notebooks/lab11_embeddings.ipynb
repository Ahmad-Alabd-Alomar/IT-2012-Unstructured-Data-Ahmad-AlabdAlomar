# %%
import os
import sys
# Pathing fix to see 'src'
sys.path.append(os.path.abspath(os.path.join('..')))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from src.embeddings.embedder import generate_embeddings, calculate_all_metrics
from src.embeddings.search_engine import SearchEngine

# 1. Load the cleaned data
df_clean = pd.read_csv("../data/processed/cleaned/cleaned_data.csv")
print(f"Clean Data shape: {df_clean.shape}")
print(f"Clean Data columns: {list(df_clean.columns)}")

# 2. Initialize the Search Engine
# This will automatically sync the CSV to ChromaDB
engine = SearchEngine(df_path="../data/processed/cleaned/cleaned_data.csv")
print("✅ Search Engine & Vector Database Initialized.")
